# %% [markdown]
# # Тестирование библиотек

# %% [markdown]
# ## Техническое задание
#
# - Протестировать библиотеку pandas_tools
# - Протестировать библиотеку ml

# %% [markdown]
# # Импорт библиотек

# %% [markdown]
# Стандартные библиотеки

# %%
import os
import sys
from tqdm import tqdm

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Частные библиотеки

# %%
os.getcwd()
# Out:
# 'd:\\Programming\\Python\\scripts'

# %%
sys.path.append('d:/Programming/Python/scripts')

# %%
from pandas_tools import DataFrame
from ml import Model, Classifier, Regressor, Clusterizer, Ranking

# %% [markdown]
# # Data Engeneering

# %% [markdown]
# ## Импорт и визуализация исходных данных

# %%
os.listdir()
# Out:
# ['decorators.py',
#  'ml.py',
#  'pandas_tools.py',
#  'pyspark_tools.py',
#  'tools.py',
#  'torch_tools.py',
#  'test_tools.py',
#  '.git',
#  '.gitignore',
#  'tensorflow_tools.py',
#  'test_ml.ipynb',
#  'venv',
#  'requirements.txt',
#  '.idea',
#  '__pycache__',
#  'cv_tools.py',
#  'datas',
#  'models_ML.py',
#  'ml_metrics.ipynb']

# %%
os.listdir('datas')
# Out:
# ['external', 'intermid', 'processed']

# %%
os.listdir('datas/external')
# Out:
# ['movies.csv']

# %%
df = pd.read_csv('./datas/external/movies.csv', sep=',')
df = DataFrame(df)
df
# Out:
# C:\Users\parkh\AppData\Local\Temp\ipykernel_6896\3134870509.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./datas/external/movies.csv', sep=',')
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# ...

# %% [markdown]
# ## Предварительная обработка

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.info(memory_usage=True)
# Out:
# <class 'pandas_tools.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.drop(['belongs_to_collection', 'imdb_id', 'poster_path'], axis=1, inplace=True)

# %% [markdown]
# ## Обработка типов данных

# %%
df.dtypes
# Out:
# adult                    object
# budget                   object
# genres                   object
# homepage                 object
# id                       object
# original_language        object
# original_title           object
# overview                 object
# popularity               object
# poster_path              object
# production_companies     object
# production_countries     object
# release_date             object
# revenue                 float64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# video                    object
# vote_average            float64
# vote_count              float64
# dtype: object

# %%
df.numeric_features
# Out:
# ['revenue', 'runtime', 'vote_average', 'vote_count']

# %%
df.categorical_features
# Out:
# ['adult',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video']

# %% [markdown]
# ## Обработка локальных пустот

# %%
df.isna().sum()
# Out:
# adult                       0
# budget                      0
# genres                      0
# homepage                37684
# id                          0
# original_language          11
# original_title              0
# overview                  954
# popularity                  5
# poster_path               386
# production_companies        3
# production_countries        3
# release_date               87
# revenue                     6
# runtime                   263
# spoken_languages            6
# status                     87
# tagline                 25054
# title                       6
# video                       6
# vote_average                6
# vote_count                  6
# dtype: int64

# %%
df.shape
# Out:
# (45466, 22)

# %% [markdown]
# ### adult

# %%
df['adult'].unique()
# Out:
# array(['False', 'True', ' - Written by Ørnås',
#        ' Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.',
#        ' Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.'],
#       dtype=object)

# %%
df = df[(df['adult'] == 'True') | (df['adult'] == 'False')]

# %%
df['adult'] = df['adult'].apply(lambda x: True if x == 'True' else False)

# %%
df['adult'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ### budget

# %%
df.head()
# Out:
#    adult    budget                                             genres  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id original_language  \
# 0  http://toystory.disney.com/toy-story    862                en
# 1                                   NaN   8844                en
# 2                                   NaN  15602                en
# 3                                   NaN  31357                en
# 4                                   NaN  11862                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# ...

# %%
df['budget'] = df['budget'].astype(np.float64).apply(lambda x: np.nan if x == 0 else x)

# %%
df.head()
# Out:
#    adult      budget                                             genres  \
# 0  False  30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         NaN  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         NaN                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id original_language  \
# 0  http://toystory.disney.com/toy-story    862                en
# 1                                   NaN   8844                en
# 2                                   NaN  15602                en
# 3                                   NaN  31357                en
# 4                                   NaN  11862                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# ...

# %% [markdown]
# ### genres

# %%
df['genres']
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45463, dtype: object

# %%
df.shape
# Out:
# (45463, 22)

# %% [markdown]
# ## Экспорт-импорт данных без локальных пропусков

# %%
df.to_csv('./datas/intermid/movies_na.csv', sep=',', encoding='utf-8', index=False)

# %%
df = pd.read_csv('./datas/intermid/movies_na.csv', sep=',', encoding='utf-8')

# %%
df
# Out:
#        adult      budget                                             genres  \
# 0      False  30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         NaN  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         NaN                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...         ...                                                ...
# 45458  False         NaN  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45459  False         NaN                      [{'id': 18, 'name': 'Drama'}]
# 45460  False         NaN  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461  False         NaN                                                 []
# 45462  False         NaN                                                 []
#
# ...

# %% [markdown]
# ## Выявление призаков

# %% [markdown]
# ### Корреляционный анализ

# %% [markdown]
# ### L1

# %% [markdown]
# ## Обработка выбросов

# %% [markdown]
# ## Понижение размерности

# %%
df.pca(5, test_size=0.25, target=target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6896\3092133674.py in ?()
# ----> 1 df.pca(5, test_size=0.25, target=target)
#
# c:\Python\Python 3.11.9\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pca'

# %%
df.lda(2, test_size=0.25, target=target)

# %%
df.nca(30, test_size=0.25, target=target)

# %% [markdown]
# ## Анализ необходимости нормализации и скалирования

# %%
df.describe().transpose()
# Out:
#                 count          mean           std  min   25%   50%    75%  \
# revenue       45460.0  1.120935e+07  6.433225e+07  0.0   0.0   0.0    0.0
# runtime       45203.0  9.412820e+01  3.840781e+01  0.0  85.0  95.0  107.0
# vote_average  45460.0  5.618207e+00  1.924216e+00  0.0   5.0   6.0    6.8
# vote_count    45460.0  1.098973e+02  4.913104e+02  0.0   3.0  10.0   34.0
#
#                        max
# revenue       2.787965e+09
# runtime       1.256000e+03
# vote_average  1.000000e+01
# vote_count    1.407500e+04

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Разделение данных для обучения и тестирования

# %%
test_size = 0.2
shuffle = True
random_state = 0

# %%
df_train, df_test = df.train_test_split(test_size=test_size, shuffle=True, random_state=random_state)
df_train.shape, df_test.shape
# Out:
# ((36370, 24), (9093, 24))

# %%
df_train.shape, df_test.shape

# %%
df_train_x = df_train.copy()
df_train_y = df_train_x.pop('target')
df_train_x.shape, df_train_y.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python\Python 3.11.9\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 df_train_x = df_train.copy()
# ...

# %%
df_test_x = df_test.copy()
df_test_y = df_test_x.pop('target')
df_test_x.shape, df_test_y.shape

# %% [markdown]
# # ML

# %%
model_ml = Model()

# %% [markdown]
# ## Обучение

# %%
model_ml.fit()

# %% [markdown]
# ## Тестирование

# %%
y_pred = DataFrame(model_ml.predict(df_test_x))

# %% [markdown]
# # DL

# %%
model_nn = 0

# %% [markdown]
# ## Обучение

# %%
model_nn.fit()

# %% [markdown]
# ## Тестирование

# %%
y_pred = DataFrame(model_nn.predict(df_test_x))
